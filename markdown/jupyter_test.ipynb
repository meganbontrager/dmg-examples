# %% [markdown]
# # Jupyter lab demo

# %% [markdown]
# In Jupyter notebooks, you can mix markdown and code in a single text file and they will render as you write

# %%
library(tidyverse)
data = read_csv("data/clean_vern.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   site = col_character(),
#   block = col_character(),
#   ID = col_character(),
#   rack = col_character(),
#   ll_cotyl = col_logical(),
#   pick_type = col_character(),
#   notes = col_logical(),
#   type = col_character(),
#   full_name = col_character()
# )
#
# See spec(...) for full column specifications.

# %% [markdown]
# A plot of stem diameters

# %%
ggplot(data, aes(x = stem_diam_mm, fill = site)) +
geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
data %>% group_by(site, block) %>% summarize(n = n())
# Out:
#    site block n
# 1  DPR  B1    40
# 2  DPR  B2    40
# 3  LV3  B1    40
# 4  LV3  B2    40
# 5  LV3  B3    25
# 6  SQ3  B1    40
# 7  SQ3  B2    31
# 8  SQ3  B3    40
# 9  WL1  B1    35
# 10 WL1  B2    34
